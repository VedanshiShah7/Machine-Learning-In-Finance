# %%
import pandas as pd
credit_card_data = pd.read_csv('/Users/vedanshi/Desktop/MLF/UCI_Credit_Card.csv')
credit_card_data
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
credit_card = credit_card_data.dropna()
credit_card
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
credit_card.columns
# age, education, marriage
# Out:
# Index(['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0',
#        'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default.payment.next.month'],
#       dtype='object')

# %%
credit_card.corr()['default.payment.next.month']
# Out:
# ID                           -0.013952
# LIMIT_BAL                    -0.153520
# SEX                          -0.039961
# EDUCATION                     0.028006
# MARRIAGE                     -0.024339
# AGE                           0.013890
# PAY_0                         0.324794
# PAY_2                         0.263551
# PAY_3                         0.235253
# PAY_4                         0.216614
# PAY_5                         0.204149
# PAY_6                         0.186866
# BILL_AMT1                    -0.019644
# BILL_AMT2                    -0.014193
# BILL_AMT3                    -0.014076
# BILL_AMT4                    -0.010156
# BILL_AMT5                    -0.006760
# BILL_AMT6                    -0.005372
# PAY_AMT1                     -0.072929
# PAY_AMT2                     -0.058579
# PAY_AMT3                     -0.056250
# PAY_AMT4                     -0.056827
# PAY_AMT5                     -0.055124
# PAY_AMT6                     -0.053183
# ...

# %%
from sklearn.model_selection import train_test_split
import statsmodels.api as sm

credit_card['bill_over_limit'] = ((credit_card['BILL_AMT1']+credit_card['BILL_AMT2']+credit_card['BILL_AMT3']+credit_card['BILL_AMT4']+credit_card['BILL_AMT5']+credit_card['BILL_AMT6'])/6)/credit_card['LIMIT_BAL']
credit_card['age_sq'] = credit_card['AGE'] ** 2
credit_card['avg_pay_score'] = (credit_card['PAY_0'] + credit_card['PAY_2'] + credit_card['PAY_3']+ credit_card['PAY_4']+ credit_card['PAY_5']+credit_card['PAY_6'])/6
# credit_card['sum_pay_over_bill'] = (credit_card['PAY_0'] + credit_card['PAY_2'] + credit_card['PAY_3']+ credit_card['PAY_4']+ credit_card['PAY_5']+credit_card['PAY_6'])/(credit_card['BILL_AMT1']+credit_card['BILL_AMT2']+credit_card['BILL_AMT3']+credit_card['BILL_AMT4']+credit_card['BILL_AMT5']+credit_card['BILL_AMT6'])

X = credit_card[['bill_over_limit', 'avg_pay_score','MARRIAGE']]
y = credit_card['default.payment.next.month']
X1 = sm.add_constant(X)

x_train, x_test, y_train, y_test = train_test_split(X1, y, test_size = 0.10, random_state = 0)
model = sm.Logit(y_train, x_train)

results = model.fit()
# results_robust = results.get_robustcov_results(cov_type = 'HC1') # hetroskedacitiy corrector
print(results.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.488602
#          Iterations 6
#                                Logit Regression Results
# ...
# Dep. Variable:     default.payment.next.month   No. Observations:                27000
# Model:                                  Logit   Df Residuals:                    26996
# Method:                                   MLE   Df Model:                            3
# Date:                        Mon, 30 Jan 2023   Pseudo R-squ.:                 0.07727
# Time:                                20:02:08   Log-Likelihood:                -13192.
# converged:                               True   LL-Null:                       -14297.
# Covariance Type:                    nonrobust   LLR p-value:                     0.000
# ...
#                       coef    std err          z      P>|z|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
credit_card['sum_pay_over_bill']
# Out:
# 0       -0.000260
# 1        0.000176
# 2        0.000000
# 3        0.000000
# 4       -0.000018
#            ...
# 29995    0.000000
# 29996   -0.000189
# 29997    0.000113
# 29998   -0.000004
# 29999    0.000000
# Name: sum_pay_over_bill, Length: 30000, dtype: float64

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_curve, roc_auc_score, mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt
import numpy as np

prob_pred = results.predict(x_test)
y_pred = [0 if x<0.25 else 1 for x in prob_pred]

mae = mean_absolute_error(y_test, y_pred)
print(f'Mean Absolute Error: {mae}')

rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f'Root Mean Squared Error: {rmse}')

r2 = r2_score(y_test, y_pred)
print(f'R-Squared: {r2}')

accuracy = accuracy_score(y_test, y_pred)
print(f'Accuracy is: {accuracy}')

classif_report = classification_report(y_test, y_pred)
print(f'Classification report is: \n {classif_report}')

cm = confusion_matrix(y_test, y_pred)
print(f'Confusion matrix is: \n {cm}')

plt.imshow(cm, cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.xlabel("Predicted label")
plt.ylabel("True label")

tick_marks = np.arange(2)
plt.xticks(tick_marks, ['pos', 'neg'])
plt.yticks(tick_marks, ['pos', 'neg'])

for i in range(2):
    for j in range(2):
        plt.text(j, i, cm[i, j], horizontalalignment="center")

plt.show()

fpr, tpr, t = roc_curve(y_test, prob_pred)
auc = roc_auc_score(y_test, prob_pred)
plt.plot(fpr, tpr, label ='AUC'+str(auc))
plt.legend()
plt.show()
# Out:
# Mean Absolute Error: 0.24033333333333334
# Root Mean Squared Error: 0.49023803741991845
# R-Squared: -0.4320709745762712
# Accuracy is: 0.7596666666666667
# Classification report is:
#                precision    recall  f1-score   support
#
#            0       0.86      0.83      0.84      2360
#            1       0.44      0.49      0.47       640
#
#     accuracy                           0.76      3000
#    macro avg       0.65      0.66      0.66      3000
# weighted avg       0.77      0.76      0.76      3000
#
# Confusion matrix is:
#  [[1964  396]
#  [ 325  315]]

# %%
plt.scatter(credit_card['avg_pay_score'], credit_card['default.payment.next.month'], marker='o', color='Blue')
plt.scatter(credit_card['bill_over_limit'], credit_card['default.payment.next.month'], marker='X', color='Red')
plt.scatter(credit_card['MARRIAGE'], credit_card['default.payment.next.month'], marker='.', color='Green')

# %%
credit_card['avg_pay_score']
# Out:
# 0       -0.333333
# 1        0.500000
# 2        0.000000
# 3        0.000000
# 4       -0.333333
#            ...
# 29995    0.000000
# 29996   -0.666667
# 29997    1.333333
# 29998   -0.166667
# 29999    0.000000
# Name: avg_pay_score, Length: 30000, dtype: float64

# %% [markdown]
# This research employed a binary variable, default payment (Yes = 1, No = 0), as the response variable. This study reviewed the literature and used the following 23 variables as explanatory variables:
# - X1: Amount of the given credit (NT dollar): it includes both the individual consumer credit and his/her family (supplementary) credit.
# - X2: Gender (1 = male; 2 = female).
# - X3: Education (1 = graduate school; 2 = university; 3 = high school; 4 = others).
# - X4: Marital status (1 = married; 2 = single; 3 = others).
# - X5: Age (year).
# - X6 - X11: History of past payment. We tracked the past monthly payment records (from April to September, 2005) as follows:
#     - X6 = the repayment status in September, 2005;
#     - X7 = the repayment status in August, 2005; . . .;
#     - X11 = the repayment status in April, 2005. The measurement scale for the repayment status is: -1 = pay duly; 1 = payment delay for one month; 2 = payment delay for two months; . . .; 8 = payment delay for eight months; 9 = payment delay for nine months and above.
# - X12-X17: Amount of bill statement (NT dollar).
#     - X12 = amount of bill statement in September, 2005;
#     - X13 = amount of bill statement in August, 2005; . . .;
#     - X17 = amount of bill statement in April, 2005.
# - X18-X23: Amount of previous payment (NT dollar).
#     - X18 = amount paid in September, 2005;
#     - X19 = amount paid in August, 2005; . . .;
#     - X23 = amount paid in April, 2005.

# %% [markdown]
# # notes
# Consider data lag

# %% [markdown]
# ## Trying out some stuff :)

# %%
import pandas as pd
credit_card_data = pd.read_csv('/Users/vedanshi/Desktop/MLF/UCI_Credit_Card.csv')
credit_card = credit_card_data.dropna()
credit_card.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0    2          2         1   24      2      2     -1     -1
# 1   2   120000.0    2          2         2   26     -1      2      0      0
# 2   3    90000.0    2          2         2   34      0      0      0      0
# 3   4    50000.0    2          2         1   37      0      0      0      0
# 4   5    50000.0    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# ...

# %%
credit_card['EDUCATION'].unique()
# Out:
# array([2, 1, 3, 5, 4, 6, 0])

# %%
credit_card['MARRIAGE'].unique()
# Out:
# array([1, 2, 3, 0])

# %%
credit_card['SEX'].unique()
# Out:
# array([2, 1])

# %%
credit_card['avg_pay'] = credit_card[["PAY_0", "PAY_2", "PAY_3", "PAY_4", "PAY_5", "PAY_6"]].mean(axis=1)
credit_card['avg_bill_amt'] = credit_card[["BILL_AMT1", "BILL_AMT2", "BILL_AMT3", "BILL_AMT4", "BILL_AMT5", "BILL_AMT6"]].mean(axis=1)
credit_card['avg_pay_amt'] = credit_card[["PAY_AMT1", "PAY_AMT2", "PAY_AMT3", "PAY_AMT4", "PAY_AMT5", "PAY_AMT6"]].mean(axis=1)
credit_card
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
# 1=yes, 0=no
credit_card['default.payment.next.month'].unique()
# Out:
# array([1, 0])

# %%
# Count the number of defaults
default_count = credit_card['default.payment.next.month'].sum()

# Count the total number of credit card holders
total_count = len(credit_card)

# Calculate the default rate as a percentage
default_rate = default_count / total_count * 100

print('Default rate: {:.2f}%'.format(default_rate))
# Out:
# Default rate: 22.12%

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, confusion_matrix

df = credit_card

# Split the data into train and test sets
X = df[['LIMIT_BAL','SEX', 'EDUCATION', 'MARRIAGE', 'AGE','avg_pay', 'avg_bill_amt', 'avg_pay_amt']]
y = df["default.payment.next.month"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Train the model
model = LogisticRegression()
model.fit(X_train, y_train)

# Predict the default rate
y_pred = model.predict(X_test)

# Calculate the accuracy
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Plot the confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)

import matplotlib.pyplot as plt
# not sure of the labels == we might wanna change it hehe
plt.imshow(cm, cmap=plt.cm.Blues)
plt.title("Confusion Matrix")
plt.xlabel("Predicted label")
plt.ylabel("True label")

tick_marks = np.arange(2)
plt.xticks(tick_marks, ['pos', 'neg'])
plt.yticks(tick_marks, ['pos', 'neg'])

for i in range(2):
    for j in range(2):
        plt.text(j, i, cm[i, j], horizontalalignment="center")

plt.show()
# Out:
# Accuracy: 0.774
# Confusion Matrix:
#  [[4644    0]
#  [1356    0]]
